# %%
import pandas as pd

# %%
path_syn = "../sdg-models/tabsyn/synthetic/adult/tabsyn.csv"

# %%
df_syn = pd.read_csv(path_syn)

# %%
df_syn
# Out:
#         age     workclass     fnlwgt  education  education.num  \
# 0      38.0           NaN  217196.11  Bachelors      10.000000
# 1      19.0   Federal-gov  136005.45       12th      10.000000
# 2      47.0   Without-pay  193150.05       10th       9.000000
# 3      30.0       Private  217512.55    1st-4th       9.000000
# 4      31.0   Federal-gov   79372.29  Doctorate      10.000000
# ...     ...           ...        ...        ...            ...
# 32556  48.0  Never-worked  233031.48       12th      10.000000
# 32557  47.0   Federal-gov  193957.23  Doctorate      10.000000
# 32558  24.0   Federal-gov  160947.30  Bachelors      10.000000
# 32559  38.0   Federal-gov  203776.50       12th       9.948622
# 32560  34.0   Federal-gov  177547.95  Bachelors       9.000000
#
#            marital.status        occupation relationship                race  \
# 0           Never-married   Exec-managerial    Unmarried               White
# 1           Never-married  Transport-moving    Unmarried               Other
# 2      Married-civ-spouse   Exec-managerial    Unmarried               White
# 3      Married-civ-spouse   Exec-managerial    Unmarried               Other
# 4           Never-married  Transport-moving    Unmarried               White
# ...                   ...               ...          ...                 ...
# 32556  Married-civ-spouse  Transport-moving    Unmarried               White
# 32557  Married-civ-spouse  Transport-moving    Unmarried               White
# 32558       Never-married   Exec-managerial    Unmarried  Asian-Pac-Islander
# 32559  Married-civ-spouse     Other-service    Unmarried               White
# 32560  Married-civ-spouse   Exec-managerial    Unmarried               Other
#
#           sex  capital.gain  capital.loss  hours.per.week native.country  \
# 0      Female           0.0           0.0       40.000000           Iran
# 1        Male           0.0           0.0       40.000000           Iran
# 2        Male           0.0           0.0       40.000000           Iran
# 3        Male           0.0           0.0       45.355198           Iran
# 4      Female           0.0           0.0       40.000000           Iran
# ...       ...           ...           ...             ...            ...
# 32556    Male           0.0           0.0       40.000000           Iran
# 32557    Male           0.0           0.0       50.000000           Iran
# 32558    Male           0.0           0.0       40.000000           Iran
# 32559    Male           0.0           0.0       40.000000           Iran
# 32560  Female           0.0           0.0       35.000000           Iran
#
#       income
# 0      <=50K
# 1      <=50K
# 2      <=50K
# 3      <=50K
# 4      <=50K
# ...      ...
# 32556  <=50K
# 32557  <=50K
# 32558  <=50K
# 32559  <=50K
# 32560  <=50K
#
# [32561 rows x 15 columns]

# %%
df_syn["income"].value_counts()
# Out:
# income
# <=50K    32364
# >50K       197
# Name: count, dtype: int64

# %%
df_syn["native.country"].value_counts()
# Out:
# native.country
# Iran             30396
# United-States     2087
# Cambodia            74
# Yugoslavia           4
# Name: count, dtype: int64

# %%
path_syn = "../sdg-models/tabsyn/synthetic/adult/tabsyn_new.csv"

# %%
df_syn = pd.read_csv(path_syn)

# %%
df_syn
# Out:
#              age         workclass     fnlwgt    education  education.num  \
# 0      25.483408           Private  157694.11      7th-8th           11.0
# 1      36.000000           Private  230668.60      Masters           12.0
# 2      37.000000  Self-emp-not-inc  225013.77    Preschool            9.0
# 3      38.000000           Private  155860.75  Prof-school           10.0
# 4      26.000000           Private  105220.44         11th           10.0
# ...          ...               ...        ...          ...            ...
# 32556  24.000000           Private  111535.00      1st-4th           10.0
# 32557  31.000000           Private  222109.33  Prof-school           11.0
# 32558  36.000000           Private  106611.48         11th           12.0
# 32559  35.000000           Private  223481.22  Prof-school           10.0
# 32560  30.000000           Private   98018.41      1st-4th            9.0
#
#            marital.status        occupation relationship   race     sex  \
# 0      Married-civ-spouse      Craft-repair      Husband  White    Male
# 1      Married-civ-spouse      Craft-repair      Husband  White    Male
# 2      Married-civ-spouse      Craft-repair      Husband  White  Female
# 3      Married-civ-spouse  Transport-moving      Husband  White    Male
# 4      Married-civ-spouse  Transport-moving      Husband  White  Female
# ...                   ...               ...          ...    ...     ...
# 32556  Married-civ-spouse      Craft-repair      Husband  Other  Female
# 32557  Married-civ-spouse      Craft-repair      Husband  White    Male
# 32558  Married-civ-spouse      Craft-repair      Husband  White    Male
# 32559       Never-married      Adm-clerical      Husband  White  Female
# 32560  Married-civ-spouse  Transport-moving      Husband  White    Male
#
#        capital.gain  capital.loss  hours.per.week   native.country income
# 0               0.0           0.0         50.0000            India  <=50K
# 1               0.0           0.0         55.8321             Peru  <=50K
# 2               0.0           0.0         40.0000            India  <=50K
# 3               0.0           0.0         40.0000  Trinadad&Tobago  <=50K
# 4               0.0           0.0         40.0000             Peru  <=50K
# ...             ...           ...             ...              ...    ...
# 32556           0.0           0.0         40.0000             Peru  <=50K
# 32557           0.0           0.0         40.0000            India  <=50K
# 32558           0.0           0.0         40.0000  Trinadad&Tobago  <=50K
# 32559           0.0           0.0         40.0000         Portugal  <=50K
# 32560           0.0           0.0         38.0000             Peru  <=50K
#
# [32561 rows x 15 columns]

# %%
df_syn["income"].value_counts()
# Out:
# income
# <=50K    31758
# >50K       803
# Name: count, dtype: int64
