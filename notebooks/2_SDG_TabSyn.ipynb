# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
path_real = "../data/processed/cancer_tabsyn.csv" 
path_syn = "../sdg-models/tabsyn/synthetic/cancer/tabsyn.csv"

# %%
df_real = pd.read_csv(path_real)
df_syn = pd.read_csv(path_syn)

# %%
df_real
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df_syn
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           B    14.200760     19.909143        83.99189  646.22610
# 1           M    12.445618     18.804281        84.75854  582.77700
# 2           B    13.146510     20.718163        82.61106  617.03090
# 3           M    13.498883     19.824331        81.37600  635.79156
# 4           B    14.740349     18.735823        85.02617  637.26190
# ..        ...          ...           ...             ...        ...
# 507         M    13.224908     19.373600        86.92173  688.88226
# 508         M    12.968764     18.828340        88.56602  563.70400
# 509         B    13.811143     18.347122        85.05302  557.96136
# 510         M    12.754508     18.415466        86.76898  604.81720
# 511         B    13.233110     21.285263        82.40703  720.88680
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df_real["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df_syn["diagnosis"].value_counts()
# Out:
# diagnosis
# B    375
# M    137
# Name: count, dtype: int64

# %%
from sdv.metadata import Metadata

# %%
metadata = Metadata.detect_from_dataframe(
    data = df_syn,
    table_name= "cancer-tabsyn" 
)

# %%
from sdv.evaluation.single_table import run_diagnostic, evaluate_quality

# %%
diagnostic = run_diagnostic(
    real_data=df_real,
    synthetic_data=df_syn,
    metadata=metadata
)#
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 32/32 [00:00<00:00, 1624.20it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 412.87it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
quality_report = evaluate_quality(
    real_data=df_real,
    synthetic_data=df_syn,
    metadata=metadata)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 32/32 [00:00<00:00, 517.73it/s]|
# Column Shapes Score: 66.31%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 496/496 [00:01<00:00, 425.31it/s]|
# Column Pair Trends Score: 75.91%
#
# Overall Score (Average): 71.11%
