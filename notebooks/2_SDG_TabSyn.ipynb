# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
path_real = "../sdg-models/tabsyn/synthetic/adult/real.csv" 
path_syn = "../sdg-models/tabsyn/synthetic/adult/tabsyn.csv"

# %%
df_real = pd.read_csv(path_real)
df_syn = pd.read_csv(path_syn)

# %%
df_real
# Out:
#         age     workclass    fnlwgt     education  education.num  \
# 0      35.0       Private  143058.0     Bachelors           13.0
# 1      60.0       Private  325971.0       HS-grad            9.0
# 2      47.0       Private  183522.0  Some-college           10.0
# 3      31.0     State-gov  161631.0  Some-college           10.0
# 4      41.0       Private   49797.0  Some-college           10.0
# ...     ...           ...       ...           ...            ...
# 15677  30.0       Private  231826.0  Some-college           10.0
# 15678  32.0       Private   37070.0     Assoc-voc           11.0
# 15679  48.0  Self-emp-inc  382242.0     Doctorate           16.0
# 15680  39.0       Private   96452.0       Masters           14.0
# 15681  39.0       Private   58343.0  Some-college           10.0
#
#            marital.status         occupation   relationship   race     sex  \
# 0      Married-civ-spouse     Prof-specialty        Husband  White    Male
# ...

# %%
df_real["income"].value_counts()
# Out:
# income
# <=50K    7841
# >50K     7841
# Name: count, dtype: int64

# %%
df_syn
# Out:
#              age         workclass      fnlwgt    education  education.num  \
# 0      25.000000           Private  158438.840      HS-grad            9.0
# 1      61.964825  Self-emp-not-inc   55712.227   Assoc-acdm           12.0
# 2      56.000000           Private  177650.780      HS-grad            9.0
# 3      42.000000           Private  176665.560    Assoc-voc           13.0
# 4      43.000000           Private  200199.620      Masters           14.0
# ...          ...               ...         ...          ...            ...
# 33753  35.000000         Local-gov  564228.900         10th            9.0
# 33754  23.000000           Private  162021.550      HS-grad            9.0
# 33755  30.000000           Private  156882.780      HS-grad            9.0
# 33756  43.003124  Self-emp-not-inc  289768.940  Prof-school           15.0
# 33757  51.000000           Private  407067.720   Assoc-acdm           12.0
#
# ...

# %%
df_syn["income"].value_counts()
# Out:
# income
# >50K     17259
# <=50K    16499
# Name: count, dtype: int64

# %%
df_real["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df_syn["diagnosis"].value_counts()
# Out:
# diagnosis
# B    375
# M    137
# Name: count, dtype: int64

# %%
from sdv.metadata import Metadata

# %%
metadata = Metadata.detect_from_dataframe(
    data = df_syn,
    table_name= "cancer-tabsyn" 
)

# %%
from sdv.evaluation.single_table import run_diagnostic, evaluate_quality

# %%
diagnostic = run_diagnostic(
    real_data=df_real,
    synthetic_data=df_syn,
    metadata=metadata
)#
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 32/32 [00:00<00:00, 1624.20it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 412.87it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
quality_report = evaluate_quality(
    real_data=df_real,
    synthetic_data=df_syn,
    metadata=metadata)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 32/32 [00:00<00:00, 517.73it/s]|
# Column Shapes Score: 66.31%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 496/496 [00:01<00:00, 425.31it/s]|
# Column Pair Trends Score: 75.91%
#
# Overall Score (Average): 71.11%
