# %% [markdown]
# # CTAB GAN Plus
#
#
# Problem:
# - cant get the right scikit-learn version anymore
# - Model is not implemented as callable object
# - Need to downlaod the whole github repo an call objects myself from the repo
#
#
#
# Env: ctab-gan-plus-env
#
# Repo: https://github.com/Team-TUD/CTAB-GAN-Plus-DP
# Paper: https://arxiv.org/abs/2204.00401

# %%
import pandas as pd
# Out:
# Running cells with 'ctab-gan-plus-env (Python 3.9.20)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/markusmuller/.pyenv/versions/ctab-gan-plus-env/bin/python -m pip install ipykernel -U --force-reinstall'
