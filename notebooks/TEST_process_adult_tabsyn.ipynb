# %%
import pandas as pd

# %%
train_path = "../sdg-models/tabsyn/data/adult/adult.data"

# %%
train_df = pd.read_csv(train_path, header=None, skipinitialspace=True)

# %%
train_df
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
train_df[14].value_counts()
# Out:
# 14
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
train_df[train_df[14] == "<=50K"]
# Out:
#        0                 1       2             3   4                   5   \
# 0      39         State-gov   77516     Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311     Bachelors  13  Married-civ-spouse
# 2      38           Private  215646       HS-grad   9            Divorced
# 3      53           Private  234721          11th   7  Married-civ-spouse
# 4      28           Private  338409     Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...           ...  ..                 ...
# 32553  32           Private  116138       Masters  14       Never-married
# 32555  22           Private  310152  Some-college  10       Never-married
# 32556  27           Private  257302    Assoc-acdm  12  Married-civ-spouse
# 32558  58           Private  151910       HS-grad   9             Widowed
# 32559  22           Private  201490       HS-grad   9       Never-married
#
#                       6              7                   8       9     10  11  \
# ...

# %%
train_df[train_df[14] == ">50K"]
# Out:
#        0                 1       2             3   4                   5   \
# 7      52  Self-emp-not-inc  209642       HS-grad   9  Married-civ-spouse
# 8      31           Private   45781       Masters  14       Never-married
# 9      42           Private  159449     Bachelors  13  Married-civ-spouse
# 10     37           Private  280464  Some-college  10  Married-civ-spouse
# 11     30         State-gov  141297     Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...           ...  ..                 ...
# 32539  71                 ?  287372     Doctorate  16  Married-civ-spouse
# 32545  39         Local-gov  111499    Assoc-acdm  12  Married-civ-spouse
# 32554  53           Private  321865       Masters  14  Married-civ-spouse
# 32557  40           Private  154374       HS-grad   9  Married-civ-spouse
# 32560  52      Self-emp-inc  287927       HS-grad   9  Married-civ-spouse
#
#                       6              7                   8       9      10  \
# ...

# %%
minority_df = train_df[train_df[14] == ">50K"]
majoirty_df = train_df[train_df[14] == "<=50K"]

# %%
minority_df.shape
# Out:
# (7841, 15)

# %%
min_size =len(minority_df)

# %%
min_size
# Out:
# 7841

# %%
majority_sampled = majoirty_df.sample(n = min_size, random_state=42)

# %%
pd.concat([minority_df, majority_sampled]).sample(frac=1, random_state=42)[14].value_counts()
# Out:
# 14
# <=50K    7841
# >50K     7841
# Name: count, dtype: int64
