# %%
from imblearn.over_sampling import SMOTENC, SMOTE
import json
import pandas as pd

# %%
data_path = "data/processsed/adult/train_min.csv"
info_path = "data/info/adult.json"

train_df = pd.read_csv(dat)
